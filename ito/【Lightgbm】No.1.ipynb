# %% [markdown]
# # LB 0.6752514

# %%
# !pip install -r requirements.txt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm_notebook as tqdm

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
# Out:
# Requirement already satisfied: lightgbm in /home/jupyter/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (4.3.0)
# Collecting polars (from -r requirements.txt (line 2))
#   Obtaining dependency information for polars from https://files.pythonhosted.org/packages/f6/c7/412912cc735bec03de751e506c3380ae393032f2e786e2a93d160acbf1dd/polars-0.20.6-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached polars-0.20.6-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: pycaret in /home/jupyter/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.2.0)
# Collecting mlflow (from -r requirements.txt (line 4))
#   Obtaining dependency information for mlflow from https://files.pythonhosted.org/packages/b6/ae/06a299c661262aad52997e07d0e5fae5b5682401afc061fdb7c8f2103780/mlflow-2.10.0-py3-none-any.whl.metadata
#   Using cached mlflow-2.10.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: scipy in /home/jupyter/.local/lib/python3.10/site-packages (from lightgbm->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (6.8.0)
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (8.1.1)
# Requirement already satisfied: jinja2>=1.2 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.3.2)
# Collecting kaleido>=0.2.1 (from pycaret->-r requirements.txt (line 3))
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: matplotlib<=3.6,>=3.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (5.9.2)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.58.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (5.17.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (5.9.3)
# Requirement already satisfied: pyod>=1.0.8 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: schemdraw==0.15 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.15)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.3.7)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: tbats>=1.1.3 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (4.66.1)
# Collecting xxhash (from pycaret->-r requirements.txt (line 3))
#   Obtaining dependency information for xxhash from https://files.pythonhosted.org/packages/80/8a/1dd41557883b6196f8f092011a5c1f72d4d44cf36d7b67d4a5efe3127949/xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: yellowbrick>=1.4 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r requirements.txt (line 3)) (1.5)
# Collecting wurlitzer (from pycaret->-r requirements.txt (line 3))
#   Using cached wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (8.1.7)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow->-r requirements.txt (line 4))
#   Obtaining dependency information for databricks-cli<1,>=0.8.7 from https://files.pythonhosted.org/packages/ae/a3/d56f8382c40899301f327d1c881278b09c9b8bc301c2c111633a0346d06e/databricks_cli-0.18.0-py2.py3-none-any.whl.metadata
#   Using cached databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (3.1.37)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: pytz<2024 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: packaging<24 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (23.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow->-r requirements.txt (line 4))
#   Obtaining dependency information for alembic!=1.10.0,<2 from https://files.pythonhosted.org/packages/7f/50/9fb3a5c80df6eb6516693270621676980acd6d5a9a7efdbfa273f8d616c7/alembic-1.13.1-py3-none-any.whl.metadata
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (6.1.3)
# Requirement already satisfied: Flask<4 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (3.0.1)
# Collecting querystring-parser<2 (from mlflow->-r requirements.txt (line 4))
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (2.0.21)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (13.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r requirements.txt (line 4)) (3.5.1)
# Collecting gunicorn<22 (from mlflow->-r requirements.txt (line 4))
#   Obtaining dependency information for gunicorn<22 from https://files.pythonhosted.org/packages/0e/2a/c3a878eccb100ccddf45c50b6b8db8cf3301a6adede6e31d48e8531cab13/gunicorn-21.2.0-py3-none-any.whl.metadata
#   Using cached gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 4))
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/2b/8d/9f11d0b9ac521febb806e7f30dc5982d0f4f5821217712c59005fbc5c1e3/Mako-1.3.2-py3-none-any.whl.metadata
#   Using cached Mako-1.3.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow->-r requirements.txt (line 4)) (4.0.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.8.1->pycaret->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (5.10.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r requirements.txt (line 3)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (10.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (4.19.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (5.3.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.55.0->pycaret->-r requirements.txt (line 3)) (0.41.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=5.0.0->pycaret->-r requirements.txt (line 3)) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in /home/jupyter/.local/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3)) (2.14.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3)) (3.9.12)
# Collecting tsdownsample==0.1.2 (from plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3))
#   Using cached tsdownsample-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r requirements.txt (line 3)) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: deprecated>=1.2.13 in /opt/conda/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r requirements.txt (line 3)) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in /home/jupyter/.local/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r requirements.txt (line 3)) (0.5.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 4)) (2.0.2)
# Collecting dash-html-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3))
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3))
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3))
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3)) (1.3.4)
# Requirement already satisfied: ansi2html in /home/jupyter/.local/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3)) (1.9.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r requirements.txt (line 3)) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/jupyter/.local/lib/python3.10/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (0.10.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret->-r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r requirements.txt (line 3)) (0.2.2)
# Using cached polars-0.20.6-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.8 MB)
# Using cached mlflow-2.10.0-py3-none-any.whl (19.5 MB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
# Using cached gunicorn-21.2.0-py3-none-any.whl (80 kB)
# Using cached xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Using cached Mako-1.3.2-py3-none-any.whl (78 kB)
# Installing collected packages: kaleido, dash-table, dash-html-components, dash-core-components, xxhash, wurlitzer, tsdownsample, querystring-parser, polars, Mako, gunicorn, databricks-cli, alembic, mlflow
# Successfully installed Mako-1.3.2 alembic-1.13.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 databricks-cli-0.18.0 gunicorn-21.2.0 kaleido-0.2.1 mlflow-2.10.0 polars-0.20.6 querystring-parser-1.2.4 tsdownsample-0.1.2 wurlitzer-3.0.3 xxhash-3.4.1

# %%
df = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample.csv', header=None)
new_index = range(42307, 42307 + len(test))
test.index = new_index

# %%
def preprocess(df, replace_dict=None, ce_dict=None):

    # 借り手の会社に関する変数（Sector, FranchiseCode）
    # 31-33, 44-45, 48-49 は同じらしい => 32,33を31に, 45を44に, 49を48に変換
    code_dict = {
        32: 31,
        33: 31,
        45: 44,
        49: 48
    }
    df["Sector"] = df["Sector"].replace(code_dict)

    # 今回の借り入れに関する変数（RevLineCr, LowDoc）
    # 公式ページには値の候補が2つ（YesとNoのYN）と記載があるが、実際の値の種類は2より多い。YN以外はNaNへ置換
    revline_dict = {'0': np.nan, 'T': np.nan}
    df["RevLineCr"] = df["RevLineCr"].replace(revline_dict)

    lowdoc_dict = {'C': np.nan, '0': np.nan, 'S': np.nan, 'A': np.nan}
    df["LowDoc"] = df["LowDoc"].replace(lowdoc_dict)

    # 日付系の変数（DisbursementDate, ApprovalDate）
    # 日付型へ変更 → 年を抽出（借りた月や日にはあまり意味はないと思われるため）
    df['DisbursementDate'] = pd.to_datetime(df['DisbursementDate'], format='%d-%b-%y')
    df["DisbursementYear"] = df["DisbursementDate"].dt.year

    # 本来数値型のものを変換する
    cols = ["DisbursementGross", "GrAppv", "SBA_Appv"]
    df[cols] = df[cols].applymap(lambda x: x.strip().replace('$', '').replace(',', '')).astype(float).astype(int)

    # 特徴量エンジニアリング
    df["FY_Diff"] = df["ApprovalFY"] - df["DisbursementYear"]
    df["State_is_BankState"] = (df["State"] == df["BankState"])
    df["State_is_BankState"] = df["State_is_BankState"].replace({True: 1, False: 0})

    df['SBA_Portion'] = df['SBA_Appv'] / df['GrAppv']
    df["DisbursementGrossRatio"] = df["DisbursementGross"] / df["GrAppv"]
    df["MonthlyRepayment"] = df["GrAppv"] / df["Term"]
    df["NullCount"] = df.isnull().sum(axis=1)

    # カテゴリカル変数の設定
    df[cols_category] = df[cols_category].fillna(-1)

    # train
    if replace_dict is None:
        # countencode, labelencode
        # ce_dict: 列名を入れるとそのカテゴリのデータがどのくらいあるかを返してくれます
        # replace_dict: 列名を入れるとlabelencodeのための数字を返してくれます
        ce_dict = {}
        replace_dict = {}
        for col in cols_category:
            replace_dict[col] = {}
            vc = df[col].value_counts()
            ce_dict[col] = vc
            replace_dict_in_dict = {}
            for i, k in enumerate(vc.keys()):
                replace_dict_in_dict[k] = i
            replace_dict[col] = replace_dict_in_dict
            df[f"{col}_CountEncode"] = df[col].replace(vc).astype(int)
            df[col] = df[col].replace(replace_dict_in_dict).astype(int)
        return df, replace_dict, ce_dict

    # test
    else:
        for col in cols_category:
            # カウントエンコード
            test_vals_uniq = df[col].unique()
            ce_dict_in_dict = ce_dict[col]
            for test_val in test_vals_uniq:
                if test_val not in ce_dict_in_dict.keys():
                    ce_dict_in_dict[test_val] = -1
            df[f"{col}_CountEncode"] = df[col].replace(ce_dict_in_dict).astype(int)

            # LabelEncode
            test_vals_uniq = df[col].unique()
            replace_dict_in_dict = replace_dict[col]
            for test_val in test_vals_uniq:
                if test_val not in replace_dict_in_dict.keys():
                    replace_dict_in_dict[test_val] = -1
            df[col] = df[col].replace(replace_dict_in_dict).astype(int)
        return df
    df.drop(["DisbursementDate", "ApprovalDate","City"], axis=1, inplace=True)

# %%
cols_category = []
for col in df.columns:
    if df[col].dtypes == 'object':
        cols_category.append(col)

# %%
df, replace_dict, ce_dict = preprocess(df)

test_df = preprocess(test, replace_dict, ce_dict)

# %%
X = df.drop('MIS_Status',axis=1)
y = df['MIS_Status']

# %%
from sklearn.utils import class_weight
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights = dict(zip(np.unique(y), weights))

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import f1_score,roc_auc_score
from sklearn.model_selection import StratifiedKFold
import statistics
from scipy.stats import mode

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import statistics
from scipy.stats import mode

average_f1 = []
average_roc_auc_score = []
predictions = []
skf = StratifiedKFold(n_splits=5)
for train_idx, val_idx in skf.split(X,y):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    params = {
        'objective': 'binary',
        'metric': 'f1',
        'class_weight': class_weights,
        "n_estimators": 3000,
        "learning_rate": 0.01,
        "colsample_bytree": 0.8,
        "subsample_freq": 1,
        "subsample": 0.8,
        "random_seed": 0,
        'verbose': -1,
    }

    model = lgb.LGBMClassifier(**params)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)])
    y_pred = model.predict(X_val)
    mean_f1 = f1_score(y_val, y_pred, average='macro')
    roc_auc = roc_auc_score(y_val, y_pred)
    average_f1.append(mean_f1)
    average_roc_auc_score.append(roc_auc)
    feature_gains = model.booster_.feature_importance(importance_type='gain')
    feature = pd.DataFrame({'feature': X.columns, 'importance': feature_gains})
    feature.sort_values(by='importance',ascending=False)
    print(feature)
    print(f"Mean F1 Score (Macro F1 Score) : {mean_f1}")
    print(f"ROC_AUC_Score : {roc_auc}")
    
    
average_f1 = statistics.mean(average_f1)
average_roc_auc_score = statistics.mean(average_roc_auc_score)
print(' ')
print(f'Average_f1marco : {average_f1}')
print(f'Average_roc_auc : {average_roc_auc_score}')
# Out:
#                           feature     importance
# 0                            Term   79171.405820
# 1                           NoEmp   91309.713784
# 2                        NewExist    6219.099139
# 3                       CreateJob   29779.766485
# 4                     RetainedJob   35527.159718
# 5                   FranchiseCode   20953.661209
# 6                       RevLineCr   16984.197553
# 7                          LowDoc   41247.381439
# 8                DisbursementDate   65284.307626
# 9                          Sector   33056.961220
# 10                   ApprovalDate   84301.015760
# 11                     ApprovalFY   36213.887647
# 12                           City   69761.493505
# 13                          State   35324.321803
# 14                      BankState   34186.859103
# 15              DisbursementGross   53620.676730
# 16                         GrAppv   42374.873174
# 17                       SBA_Appv   59151.750692
# 18                     UrbanRural  126512.161096
# 19               DisbursementYear   40703.264146
# 20                        FY_Diff   50108.652164
# 21             State_is_BankState    6287.058511
# 22                    SBA_Portion   17302.194443
# 23         DisbursementGrossRatio   22164.798160
# 24               MonthlyRepayment   71567.249022
# 25                      NullCount   13792.825063
# 26          RevLineCr_CountEncode    3885.889573
# 27             LowDoc_CountEncode   11983.388243
# 28   DisbursementDate_CountEncode   25531.135220
# 29       ApprovalDate_CountEncode   23692.378900
# 30               City_CountEncode   23513.023445
# 31              State_CountEncode   13057.929699
# 32          BankState_CountEncode   11689.120967
# 33  DisbursementGross_CountEncode   17146.023002
# 34             GrAppv_CountEncode   10427.056634
# 35           SBA_Appv_CountEncode   16140.586339
# Mean F1 Score (Macro F1 Score) : 0.6500547061358929
# ROC_AUC_Score : 0.6883981588072485
#                           feature     importance
# 0                            Term   78914.972164
# 1                           NoEmp  101223.220503
# 2                        NewExist    7042.188365
# 3                       CreateJob   33156.186558
# 4                     RetainedJob   37117.420907
# 5                   FranchiseCode   21161.612767
# 6                       RevLineCr   16401.625131
# 7                          LowDoc   39397.546376
# 8                DisbursementDate   67867.942331
# 9                          Sector   31604.443607
# 10                   ApprovalDate   83664.190595
# 11                     ApprovalFY   38342.059556
# 12                           City   67664.323660
# 13                          State   32210.009842
# 14                      BankState   32975.831395
# 15              DisbursementGross   48515.525670
# 16                         GrAppv   39695.389804
# 17                       SBA_Appv   58774.467294
# 18                     UrbanRural  123600.920939
# 19               DisbursementYear   41515.955773
# 20                        FY_Diff   49755.967993
# 21             State_is_BankState    7989.038786
# 22                    SBA_Portion   17204.104300
# 23         DisbursementGrossRatio   21659.686854
# 24               MonthlyRepayment   72678.094115
# 25                      NullCount   15693.025471
# 26          RevLineCr_CountEncode    4591.040696
# 27             LowDoc_CountEncode   11503.735828
# 28   DisbursementDate_CountEncode   24567.746154
# 29       ApprovalDate_CountEncode   25583.463174
# 30               City_CountEncode   23828.598320
# 31              State_CountEncode   11704.097072
# 32          BankState_CountEncode   11464.658521
# 33  DisbursementGross_CountEncode   14795.127194
# 34             GrAppv_CountEncode   10682.416235
# 35           SBA_Appv_CountEncode   15798.312031
# Mean F1 Score (Macro F1 Score) : 0.6468374373426308
# ROC_AUC_Score : 0.6985159130326262
#                           feature     importance
# 0                            Term   74305.288551
# 1                           NoEmp  101366.300063
# 2                        NewExist    4191.027830
# 3                       CreateJob   32965.157185
# 4                     RetainedJob   35698.465033
# 5                   FranchiseCode   22200.563087
# 6                       RevLineCr   18143.590485
# 7                          LowDoc   43839.853153
# 8                DisbursementDate   66108.499027
# 9                          Sector   31072.356979
# 10                   ApprovalDate   85695.256256
# 11                     ApprovalFY   36895.710114
# 12                           City   67721.147997
# 13                          State   34335.271025
# 14                      BankState   34557.246150
# 15              DisbursementGross   55706.264846
# 16                         GrAppv   40342.923737
# 17                       SBA_Appv   56201.288619
# 18                     UrbanRural  122428.866539
# 19               DisbursementYear   39677.052078
# 20                        FY_Diff   46945.667316
# 21             State_is_BankState    6945.625190
# 22                    SBA_Portion   16823.399095
# 23         DisbursementGrossRatio   23533.021661
# 24               MonthlyRepayment   73033.645420
# 25                      NullCount   15083.504445
# 26          RevLineCr_CountEncode    4587.555133
# 27             LowDoc_CountEncode   13608.073084
# 28   DisbursementDate_CountEncode   22983.734899
# 29       ApprovalDate_CountEncode   25335.443573
# 30               City_CountEncode   27133.128930
# 31              State_CountEncode   12014.999876
# 32          BankState_CountEncode   11523.401576
# 33  DisbursementGross_CountEncode   15188.230647
# 34             GrAppv_CountEncode   10476.133482
# 35           SBA_Appv_CountEncode   15105.158263
# Mean F1 Score (Macro F1 Score) : 0.6521145470682155
# ROC_AUC_Score : 0.7003631022127919
#                           feature     importance
# 0                            Term   78806.243523
# 1                           NoEmp  107164.462246
# 2                        NewExist    8463.126262
# 3                       CreateJob   31344.917556
# 4                     RetainedJob   33026.949215
# 5                   FranchiseCode   21503.226968
# 6                       RevLineCr   16286.706247
# 7                          LowDoc   36275.830111
# 8                DisbursementDate   68630.188966
# 9                          Sector   35292.134996
# 10                   ApprovalDate   83186.376502
# 11                     ApprovalFY   36647.443287
# 12                           City   65620.166163
# 13                          State   36652.984127
# 14                      BankState   35555.009689
# 15              DisbursementGross   51367.624964
# 16                         GrAppv   37132.313627
# 17                       SBA_Appv   55417.910992
# 18                     UrbanRural  118827.358838
# 19               DisbursementYear   42323.550416
# 20                        FY_Diff   50049.448837
# 21             State_is_BankState    6523.434651
# 22                    SBA_Portion   16405.278016
# 23         DisbursementGrossRatio   22185.210095
# 24               MonthlyRepayment   71955.316742
# 25                      NullCount   18591.580288
# 26          RevLineCr_CountEncode    4237.714768
# 27             LowDoc_CountEncode   11269.848325
# 28   DisbursementDate_CountEncode   24715.230756
# 29       ApprovalDate_CountEncode   24248.361245
# 30               City_CountEncode   23575.324575
# 31              State_CountEncode   12555.138389
# 32          BankState_CountEncode   11661.007773
# 33  DisbursementGross_CountEncode   15303.345929
# 34             GrAppv_CountEncode   10278.473260
# 35           SBA_Appv_CountEncode   15671.940229
# Mean F1 Score (Macro F1 Score) : 0.6572937240935767
# ROC_AUC_Score : 0.7077864879666802
#                           feature     importance
# 0                            Term   78431.032484
# 1                           NoEmp   93660.506189
# 2                        NewExist    4121.813115
# 3                       CreateJob   31200.079087
# 4                     RetainedJob   31061.906891
# 5                   FranchiseCode   21629.361620
# 6                       RevLineCr   13396.263409
# 7                          LowDoc   42447.713407
# 8                DisbursementDate   69508.558390
# 9                          Sector   31792.817156
# 10                   ApprovalDate   85423.240968
# 11                     ApprovalFY   37513.995487
# 12                           City   71586.182615
# 13                          State   34245.948110
# 14                      BankState   37646.009189
# 15              DisbursementGross   55723.868392
# 16                         GrAppv   39140.008650
# 17                       SBA_Appv   56649.124319
# 18                     UrbanRural  128972.106035
# 19               DisbursementYear   41812.603487
# 20                        FY_Diff   47795.229627
# 21             State_is_BankState    7819.081215
# 22                    SBA_Portion   17534.725399
# 23         DisbursementGrossRatio   23053.936794
# 24               MonthlyRepayment   73354.131726
# 25                      NullCount   13876.107682
# 26          RevLineCr_CountEncode    4044.561608
# 27             LowDoc_CountEncode   12545.232005
# 28   DisbursementDate_CountEncode   25835.046285
# 29       ApprovalDate_CountEncode   25086.293573
# 30               City_CountEncode   21827.416869
# 31              State_CountEncode   12235.949090
# 32          BankState_CountEncode   12777.276796
# 33  DisbursementGross_CountEncode   14853.033817
# 34             GrAppv_CountEncode   10903.722452
# 35           SBA_Appv_CountEncode   15595.506849
# Mean F1 Score (Macro F1 Score) : 0.6494340357515582
# ROC_AUC_Score : 0.6943298925478746
#
# Average_f1marco : 0.6511468900783748
# Average_roc_auc : 0.6978787109134442

# %%
from sklearn import metrics
def decide_cutoff(val_y, preds_y_proba):
    mean_f1_list = []
    fpr, tpr, thresholds = metrics.roc_curve(val_y, preds_y_proba)
    for threshold in thresholds:
        preds_y = [1 if prob > threshold else 0 for prob in preds_y_proba]
        mean_f1_list.append(f1_score(val_y, preds_y, average='macro'))
    return np.max(mean_f1_list), thresholds[np.argmax(mean_f1_list)]

# %%
list_metrics_auc = []
list_metrics_f1 = []
list_cutoff = []
list_models = []
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=0)
for fold, (trn_idx, val_idx) in enumerate(cv.split(X, y), start=1):
    trn_x = X.iloc[trn_idx, :]
    trn_y = y[trn_idx]
    val_x = X.iloc[val_idx, :]
    val_y = y[val_idx]
    model_lgb = lgb.LGBMClassifier(**params)
    
    model_lgb.fit(
        trn_x, trn_y,
        eval_set=[(val_x, val_y)],
    )
    list_models.append(model_lgb)
    preds_y_proba = model_lgb.predict_proba(val_x)[:, 1]
    auc = roc_auc_score(val_y, preds_y_proba)
    f1, threshold = decide_cutoff(val_y, preds_y_proba)
    list_metrics_auc.append(auc)
    list_metrics_f1.append(f1)
    list_cutoff.append(threshold)
    print(f"Fold: {fold}, AUC: {auc}, f1 score: {f1} Threshold: {threshold}")
# Out:
# Fold: 1, AUC: 0.7620549088114816, f1 score: 0.6681857310163786 Threshold: 0.3401424796390054
# Fold: 2, AUC: 0.7771182859468214, f1 score: 0.6761518490734275 Threshold: 0.23555850097892836
# Fold: 3, AUC: 0.774128705927084, f1 score: 0.6764122165629486 Threshold: 0.33893217207184473

# %%
threshold = np.median(list_cutoff)
preds_y_proba = np.zeros(len(test))
for model in list_models:
    preds_y_proba += model.predict_proba(test[model.feature_name_])[:, 1] / len(list_models)
preds_y = [1 if prob > threshold else 0 for prob in preds_y_proba]

# %%
sample[1] = preds_y
sample[1] = sample[1].astype(int)
#sample.to_csv("submission.csv", header=False, index=False)
