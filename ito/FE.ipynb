# %%
# !pip install --user -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt
import sys
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import polars as pl
from glob import glob
from pathlib import Path
import joblib
import pickle
import itertools
from tqdm.auto import tqdm

import torch
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GroupKFold
from sklearn.metrics import log_loss, roc_auc_score, matthews_corrcoef, f1_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import xgboost as xgb
from catboost import Pool, CatBoostRegressor, CatBoostClassifier
# Out:
# Requirement already satisfied: lightgbm==4.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: polars in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 2)) (0.20.7)
# Requirement already satisfied: pycaret in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: mlflow in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: catboost in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: xgboost in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 6)) (2.0.3)
# Requirement already satisfied: torch in /home/jupyter/.local/lib/python3.10/site-packages (from -r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm==4.3.0->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: scipy in /home/jupyter/.local/lib/python3.10/site-packages (from lightgbm==4.3.0->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (6.8.0)
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (8.1.1)
# Requirement already satisfied: jinja2>=1.2 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: kaleido>=0.2.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: matplotlib<=3.6,>=3.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.9.2)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.58.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.17.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.9.3)
# Requirement already satisfied: pyod>=1.0.8 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: schemdraw==0.15 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.15)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.3.7)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: tbats>=1.1.3 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/conda/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: yellowbrick>=1.4 in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.5)
# Requirement already satisfied: wurlitzer in /home/jupyter/.local/lib/python3.10/site-packages (from pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (0.18.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.1.37)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: pytz<2024 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: packaging<24 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (23.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (6.1.3)
# Requirement already satisfied: Flask<4 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: querystring-parser<2 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2.0.21)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (13.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: gunicorn<22 in /home/jupyter/.local/lib/python3.10/site-packages (from mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: graphviz in /home/jupyter/.local/lib/python3.10/site-packages (from catboost->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 5)) (0.20.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (3.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: sympy in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (3.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/jupyter/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (12.3.101)
# Requirement already satisfied: Mako in /home/jupyter/.local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /home/jupyter/.local/lib/python3.10/site-packages (from Flask<4->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (4.0.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.8.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.10.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (10.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<=3.6,>=3.3.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (4.19.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.3.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.55.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.41.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=5.0.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in /home/jupyter/.local/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.14.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.9.12)
# Requirement already satisfied: tsdownsample==0.1.2 in /home/jupyter/.local/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: deprecated>=1.2.13 in /opt/conda/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in /home/jupyter/.local/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.5.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: mpmath>=0.19 in /home/jupyter/.local/lib/python3.10/site-packages (from sympy->torch->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.3.4)
# Requirement already satisfied: ansi2html in /home/jupyter/.local/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.9.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/jupyter/.local/lib/python3.10/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.10.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r /home/jupyter/【SIGANTE】金融分析/signate_financial/ito/requirements.txt (line 3)) (0.2.2)

# %%
# ====================================================
# Configurations
# ====================================================
class CFG:
    VER = 2
    AUTHOR = 'Ito'
    COMPETITION = 'FUDA2'
    DATA_PATH = Path('/home/jupyter/【SIGANTE】金融分析/signate_financial/ito/data')
    MODEL_DATA_PATH = Path('/home/jupyter/【SIGANTE】金融分析/signate_financial/ito/models')

    METHOD_LIST = ['lightgbm']
    seed = 28
    n_folds = 5
    target_col = 'MIS_Status'
    metric = 'f1_score'
    metric_maximize_flag = True
    num_boost_round = 1000
    early_stopping_round = 200
    verbose = 25
    classification_lgb_params = {
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': 0.05,
        'seed': seed,
    }

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %%
def lgb_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'f1score', f1_score(y_true, np.where(y_pred >= 0.5, 1, 0), average='macro'), CFG.metric_maximize_flag

# %%
train_df = pd.read_csv(CFG.DATA_PATH / 'train.csv')
test_df = pd.read_csv(CFG.DATA_PATH / 'test.csv')

# %%
def preprocess(input_df):
    input_df[['ApprovalDate', 'DisbursementDate']] = input_df[['ApprovalDate', 'DisbursementDate']].apply(pd.to_datetime)
    input_df['DiffDays'] = (input_df['DisbursementDate'] - input_df['ApprovalDate']).dt.days
    days_mean = np.mean(input_df['DiffDays'].dropna())
    input_df['ApprovalToDisbursement_days'] = input_df['DiffDays'].fillna(days_mean).astype(int)
    input_df[['ApprovalDate', 'DisbursementDate']] = input_df[['ApprovalDate', 'DisbursementDate']].apply(lambda x: x.dt.strftime('%Y-%m-%d'))
    
    for col in ['RevLineCr', 'LowDoc', 'BankState', 'DisbursementDate']:
        input_df[col] = input_df[col].fillna('[UNK]')
    
    for col in ['DisbursementGross', 'GrAppv', 'SBA_Appv']:
        input_df[col] = input_df[col].str[1:].str.replace(',', '').str.replace(' ', '').astype(float)
    
    input_df['NewExist'] = np.where(input_df['NewExist'] == 1, 1, 0)
    
    return input_df

# %%
train_df = preprocess(train_df)
test_df = preprocess(test_df)

# %%
import category_encoders as ce
def target_enc(df,test,col):
    kf = KFold(n_splits=CFG.n_folds,shuffle=True,random_state = CFG.seed)
    encoded_features = []

    for train_idx, val_idx in kf.split(df):
        X_train, X_valid = df[features].iloc[train_idx], df[features].iloc[val_idx]
        y_train = df[CFG.target_col].iloc[train_idx]

        target_encoder = ce.TargetEncoder()
        target_encoder.fit(X_train[col], y_train)

        X_valid[f'{col}_target_Encoded'] = target_encoder.transform(X_valid[col])
        encoded_features.append(X_valid)


    encoded_df = pd.concat(encoded_features).sort_index()
    df[f'{col}_target_Encoded'] = encoded_df[f'{col}_target_Encoded']
    
    target_encoder = ce.TargetEncoder()
    target_encoder.fit(df[[col]], df[CFG.target_col])

    test[f'{col}_target_Encoded'] = target_encoder.transform(test[[col]])
    
    return df, test

def encoder(df,test):
    object_columns = [col for col in df.columns if df[col].dtype == 'object']
    
    for col in object_columns:
        df,test = target_enc(df,test, col)
    
    df.drop(object_columns,axis=1,inplace=True)
    test.drop(object_columns,axis=1,inplace=True)
        
    return df,test

features = [col for col in train_df.columns if col != CFG.target_col]
train_df,test_df = encoder(train_df,test_df)
features = [col for col in train_df.columns if col != CFG.target_col]

# %%
def lightgbm_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list):
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_valid = lgb.Dataset(x_valid, y_valid)
    model = lgb.train(
                params = CFG.classification_lgb_params,
                train_set = lgb_train,
                num_boost_round = CFG.num_boost_round,
                valid_sets = [lgb_train, lgb_valid],
                feval = lgb_metric,
                callbacks=[lgb.early_stopping(stopping_rounds=CFG.early_stopping_round,
                                              verbose=CFG.verbose)]
            )
    # Predict validation
    valid_pred = model.predict(x_valid)
    
    importance_df = pd.DataFrame({
        'feature': features,
        'importance': model.feature_importance(importance_type='gain')
    })
    importance_df['importance'] = importance_df['importance'] / np.sum(importance_df['importance'])
    importance_df = importance_df.sort_values(by='importance', ascending=False)
    print(importance_df)
    return model, valid_pred

def gradient_boosting_model_cv_training(method: str, train_df: pd.DataFrame, features: list):
    oof_predictions = np.zeros(len(train_df))
    oof_fold = np.zeros(len(train_df))
    kfold = KFold(n_splits=CFG.n_folds, shuffle=True, random_state=CFG.seed)
    for fold, (train_index, valid_index) in enumerate(kfold.split(train_df)):
        print('-'*50)
        print(f'{method} training fold {fold+1}')

        x_train = train_df[features].iloc[train_index]
        y_train = train_df[CFG.target_col].iloc[train_index]
        x_valid = train_df[features].iloc[valid_index]
        y_valid = train_df[CFG.target_col].iloc[valid_index]
        if method == 'lightgbm':
            model, valid_pred = lightgbm_training(x_train, y_train, x_valid, y_valid, features)

        importance_df = pd.DataFrame(model.feature_importance(), index=features, columns=['importance'])
        importance_df['importance'] = importance_df['importance'] / np.sum(importance_df['importance'])
        importance_df.sort_values('importance', ascending=False)

        oof_predictions[valid_index] = valid_pred
        oof_fold[valid_index] = fold + 1
        del x_train, x_valid, y_train, y_valid, model, valid_pred
        gc.collect()

    score = f1_score(train_df[CFG.target_col], oof_predictions >= 0.5, average='macro')
    print(f'{method} our out of folds CV f1score is {score}')

def Learning(input_df: pd.DataFrame, features: list):
    for method in CFG.METHOD_LIST:
        gradient_boosting_model_cv_training(method, input_df, features)

# %%
Learning(train_df, features)
# Out:
# --------------------------------------------------
# lightgbm training fold 1
# [LightGBM] [Info] Number of positive: 30230, number of negative: 3615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3247
# [LightGBM] [Info] Number of data points in the train set: 33845, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.893190 -> initscore=2.123743
# [LightGBM] [Info] Start training from score 2.123743
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [51]	training's auc: 0.834992	training's f1score: 0.653433	valid_1's auc: 0.7826	valid_1's f1score: 0.631085
# --------------------------------------------------
# lightgbm training fold 2
# [LightGBM] [Info] Number of positive: 30217, number of negative: 3628
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003486 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3249
# [LightGBM] [Info] Number of data points in the train set: 33845, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892805 -> initscore=2.119723
# [LightGBM] [Info] Start training from score 2.119723
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [203]	training's auc: 0.913973	training's f1score: 0.688531	valid_1's auc: 0.79794	valid_1's f1score: 0.66547
# --------------------------------------------------
# lightgbm training fold 3
# [LightGBM] [Info] Number of positive: 30239, number of negative: 3607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002762 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3244
# [LightGBM] [Info] Number of data points in the train set: 33846, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.893429 -> initscore=2.126256
# [LightGBM] [Info] Start training from score 2.126256
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [111]	training's auc: 0.873115	training's f1score: 0.666598	valid_1's auc: 0.802772	valid_1's f1score: 0.655403
# --------------------------------------------------
# lightgbm training fold 4
# [LightGBM] [Info] Number of positive: 30191, number of negative: 3655
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003470 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3248
# [LightGBM] [Info] Number of data points in the train set: 33846, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892011 -> initscore=2.111448
# [LightGBM] [Info] Start training from score 2.111448
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [180]	training's auc: 0.90374	training's f1score: 0.693385	valid_1's auc: 0.778976	valid_1's f1score: 0.62923
# --------------------------------------------------
# lightgbm training fold 5
# [LightGBM] [Info] Number of positive: 30191, number of negative: 3655
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002574 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3241
# [LightGBM] [Info] Number of data points in the train set: 33846, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892011 -> initscore=2.111448
# [LightGBM] [Info] Start training from score 2.111448
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [163]	training's auc: 0.900343	training's f1score: 0.67955	valid_1's auc: 0.782361	valid_1's f1score: 0.646945
# lightgbm our out of folds CV f1score is 0.6460472184618609

# %% [raw]
# lightgbm our out of folds CV f1score is 0.6460472184618609
